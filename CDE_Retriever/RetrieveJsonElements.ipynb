# %% [markdown]
# # Extracting information from JSON
# J. Michael Dean, MD
# August 6, 2024
#
# The purpose here is to ingest a JSON file from the NIH NCE repository, identify the elements
# that I want to put into a CSV file, and then output the CSV file.  I will then use that file
# to feed my RAG.
#
# The CSV file provided by NIH is very minimal and does not contain enough contextual, semantic
# information to give me good retrieval.  It also contains stuff I don't care about, such as
# the steward, etc.  So I am creating this more meaningful CSV file from the JSON download.

# %%
# Install necessary modules
# !pip install -qU langchain langchain_community
# !pip install -qU pypdf
# !pip install yt_dlp
# !pip install pydub
# !pip install -qU chromadb
# !pip install -qU langchain_openai
# !pip install -qU sentence_transformers

# %%
# Load dependencies
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_community.document_loaders import JSONLoader
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# from langchain.text_splitter import RecursiveJsonSplitter
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import Chroma
from openai import OpenAI
from IPython.display import Markdown, display

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import shutil

# %%
# load JSON file
# I am just using Python code - I am not using the LangChain JSONLoader
import json
from pathlib import Path
from pprint import pprint
file_path = 'SearchExport.json'
data = json.loads(Path(file_path).read_text())

# %%
# Print the first data element in the JSON file
# pprint(data[111:113])
# Out:
# [{'__v': 0,
#   'archived': False,
#   'attachments': [],
#   'cdeTinyIds': [],
#   'changeNote': 'changed status to Qualified',
#   'classification': [{'elements': [{'elements': [{'elements': [],
#                                                   'name': 'Organ Support'}],
#                                     'name': 'CONNECTS'}],
#                       'stewardOrg': {'name': 'NHLBI'}}],
#   'classificationSize': 1,
#   'copyrightStatus': 'Public domain, free to use',
#   'created': '2022-12-09T15:09:37.100Z',
#   'createdBy': {'username': 'NIH CDE Repository Team'},
#   'dataElementConcept': {'concepts': [{'name': 'Mechanical ventilation',
#                                        'origin': 'UMLS',
#                                        'originId': 'C0199470'},
#                                       {'name': 'Non-Invasive Mechanical '
#                                                'Ventilation',
#                                        'origin': 'UMLS',
#                                        'originId': 'C2349740'}]},
#   'dataSets': [],
#   'definitions': [{'definition': 'Oxygen Support Category - categorization of '
#                                  'oxygen support as invasive or non-invasive '
#                                  'for each daily assessment.',
#                    'sources': [],
#                    'tags': []}],
#   'derivationRules': [],
#   'designations': [{'designation': 'Oxygen support category',
#                     'sources': [],
#                     'tags': []},
#                    {'designation': 'Was the oxygen support received invasive '
#                                    'or non-invasive?',
#                     'sources': [],
#                     'tags': ['Preferred Question Text']}],
#   'elementType': 'cde',
#   'history': [],
#   'ids': [{'id': 'O2CAT', 'source': 'NHLBI CONNECTS ID'}],
#   'imported': '2022-12-09T15:09:37.100Z',
#   'nihEndorsed': True,
#   'objectClass': {'concepts': []},
#   'partOfBundles': [],
#   'properties': [{'key': 'NHLBI Source',
#                   'source': 'NHLBI',
#                   'value': 'PETAL (ORCHID) { PETAL - Prevention and Early '
#                            'Treatment of Acute Lung Injury ORCHID - Outcomes '
#                            'Related to COVID-19 treated with '
#                            'Hydroxychloroquine among In-patients with '
#                            'symptomatic Disease study}, PETAL (CORAL) {PETAL - '
#                            'Prevention and Early Treatment of Acute Lung '
#                            'Injury CORAL -Repository of Electronic Data (RED) '
#                            'COVID-19 Observational Study and Prospective study '
#                            'of Biology and Longitudinal outcomes (BLUE)}'}],
#   'property': {'concepts': []},
#   'referenceDocuments': [],
#   'registrationState': {'administrativeStatus': 'Org Approve',
#                         'registrationStatus': 'Qualified'},
#   'sources': [{'imported': '2022-12-09T15:09:37.100Z', 'sourceName': 'NHLBI'}],
#   'sourcesNew': {},
#   'steward': 'NHLBI',
#   'stewardOrg': {'name': 'NHLBI'},
#   'tinyId': 'HYKkzgy09r',
#   'updatedBy': {'username': 'rtaylor'},
#   'valueDomain': {'datatype': 'Value List',
#                   'identifiers': [],
#                   'ids': [],
#                   'permissibleValues': [{'codeSystemName': 'NCI',
#                                          'conceptId': 'C0199470',
#                                          'conceptSource': 'UMLS',
#                                          'permissibleValue': 'INVASIVE',
#                                          'valueMeaningCode': 'C70909',
#                                          'valueMeaningDefinition': 'Invasive '
#                                                                    'MV - A '
#                                                                    'procedure '
#                                                                    'that '
#                                                                    'mechanically '
#                                                                    'assists or '
#                                                                    'replaces '
#                                                                    'spontaneous '
#                                                                    'breathing '
#                                                                    'in '
#                                                                    'patients '
#                                                                    'by use of '
#                                                                    'a powered '
#                                                                    'device '
#                                                                    'that '
#                                                                    'forces '
#                                                                    'oxygenated '
#                                                                    'air into '
#                                                                    'the '
#                                                                    'lungs.'},
#                                         {'codeSystemName': 'NCI',
#                                          'conceptId': 'C2349740',
#                                          'conceptSource': 'UMLS',
#                                          'permissibleValue': 'NON-INVASIVE',
#                                          'valueMeaningCode': 'C171457',
#                                          'valueMeaningDefinition': 'Non-invasive '
#                                                                    '- a type '
#                                                                    'of '
#                                                                    'mechanical '
#                                                                    'ventilation '
#                                                                    'procedure '
#                                                                    'that uses '
#                                                                    'a '
#                                                                    'non-invasive '
#                                                                    'means, '
#                                                                    'such as a '
#                                                                    'face mask '
#                                                                    'or nasal '
#                                                                    'mask, to '
#                                                                    'deliver '
#                                                                    'oxygenated '
#                                                                    'air into '
#                                                                    'the lungs'},
#                                         {'codeSystemName': 'NCI',
#                                          'conceptId': 'C0439673',
#                                          'conceptSource': 'UMLS',
#                                          'permissibleValue': 'UNKNOWN/UNCERTAIN',
#                                          'valueMeaningCode': 'C17998',
#                                          'valueMeaningDefinition': 'Unknown - '
#                                                                    'Not known, '
#                                                                    'observed, '
#                                                                    'recorded; '
#                                                                    'or '
#                                                                    'reported '
#                                                                    'as unknown '
#                                                                    'by the '
#                                                                    'data '
#                                                                    'contributor'},
#                                         {'codeSystemName': 'NCI',
#                                          'conceptId': 'C3846720',
#                                          'conceptSource': 'UMLS',
#                                          'permissibleValue': 'NOT ASSESSED',
#                                          'valueMeaningCode': 'C139527',
#                                          'valueMeaningDefinition': 'Not '
#                                                                    'assessed - '
#                                                                    'Indicates '
#                                                                    'that an '
#                                                                    'assessment '
#                                                                    'was not '
#                                                                    'performed'}]},
#   'views': 30},
#  {'__v': 1,
#   'archived': False,
#   'attachments': [],
#   'cdeTinyIds': [],
#   'changeNote': 'load Project5 on 29 March 2022',
#   'classification': [{'elements': [{'elements': [], 'name': 'Tier 1'}],
#                       'stewardOrg': {'name': 'Project 5 (COVID-19)'}}],
#   'classificationSize': 1,
#   'copyrightStatus': 'Public domain, free to use',
#   'created': '2022-03-29T15:13:59.754Z',
#   'createdBy': {'username': 'NIH CDE Repository Team'},
#   'dataElementConcept': {'concepts': [{'name': 'Parent',
#                                        'origin': 'NCI Thesaurus',
#                                        'originId': 'C42709'},
#                                       {'name': 'Education Level',
#                                        'origin': 'NCI Thesaurus',
#                                        'originId': 'C17953'}]},
#   'dataSets': [],
#   'definitions': [{'definition': 'A textual description of the grade or '
#                                  'highest level of education attained by the '
#                                  'parent.',
#                    'sources': [],
#                    'tags': []}],
#   'derivationRules': [],
#   'designations': [{'designation': "Parent's Current Educational Attainment",
#                     'sources': [],
#                     'tags': []},
#                    {'designation': 'What is the highest grade or level of '
#                                    'school you have completed or the highest '
#                                    'degree you have received?',
#                     'sources': [],
#                     'tags': ['Preferred Question Text']}],
#   'elementType': 'cde',
#   'history': [],
#   'ids': [],
#   'imported': '2022-03-29T15:13:59.754Z',
#   'nihEndorsed': True,
#   'noRenderAllowed': False,
#   'objectClass': {'concepts': []},
#   'partOfBundles': [],
#   'properties': [{'key': 'Tags/Keywords',
#                   'source': 'Project 5 (COVID-19)',
#                   'value': 'Person, Demographics, Education, SDOH Education '
#                            'Level'},
#                  {'key': 'Project 5 (COVID-19) Source',
#                   'source': 'Project 5 (COVID-19)',
#                   'value': 'Pediatrics COVID CDEs'}],
#   'property': {'concepts': []},
#   'referenceDocuments': [],
#   'registrationState': {'administrativeStatus': 'Org Approve',
#                         'registrationStatus': 'Qualified'},
#   'sources': [{'imported': '2022-03-29T15:13:59.754Z',
#                'sourceName': 'Project 5 (COVID-19)'}],
#   'sourcesNew': {},
#   'steward': 'Project 5 (COVID-19)',
#   'stewardOrg': {'name': 'Project 5 (COVID-19)'},
#   'tinyId': 'YsB4aDW97v',
#   'valueDomain': {'datatype': 'Value List',
#                   'identifiers': [],
#                   'ids': [],
#                   'permissibleValues': [{'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67122:C37998:C70432',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Never Attended/ '
#                                                              'Kindergarten '
#                                                              'Only',
#                                          'valueMeaningCode': 'Never Attended/ '
#                                                              'Kindergarten '
#                                                              'Only',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'either '
#                                                                    'never '
#                                                                    'attended '
#                                                                    'any '
#                                                                    'educational '
#                                                                    'program or '
#                                                                    'has not '
#                                                                    'completed '
#                                                                    'anything '
#                                                                    'higher '
#                                                                    'than '
#                                                                    'kindergarten. '
#                                                                    'C67122:C37998:C70432'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67123',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '1st Grade',
#                                          'valueMeaningCode': 'LA15607-7',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 1st '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67123'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67124',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '2nd Grade',
#                                          'valueMeaningCode': 'LA15608-5',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 2nd '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67124'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67125',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '3rd Grade',
#                                          'valueMeaningCode': 'LA15609-3',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 3rd '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67125'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67126',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '4th Grade',
#                                          'valueMeaningCode': 'LA15610-1',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 4th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67126'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67127',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '5th Grade',
#                                          'valueMeaningCode': 'LA15611-9',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 5th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67127'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67128',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '6th Grade',
#                                          'valueMeaningCode': 'LA15612-7',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 6th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67128'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67129',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '7th Grade',
#                                          'valueMeaningCode': 'LA15613-5',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 7th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67129'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67130',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '8th Grade',
#                                          'valueMeaningCode': 'LA15614-3',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 8th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67130'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67131',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '9th Grade',
#                                          'valueMeaningCode': 'LA15615-0',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 9th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67131'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67132',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '10th Grade',
#                                          'valueMeaningCode': 'LA15616-8',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 10th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67132'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67133',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '11th Grade',
#                                          'valueMeaningCode': 'LA15617-6',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that 11th '
#                                                                    'grade is '
#                                                                    'the '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67133'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67134',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': '12th Grade/No HS '
#                                                              'diploma',
#                                          'valueMeaningCode': 'LA15618-4',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person was '
#                                                                    'in school '
#                                                                    'through '
#                                                                    '12th grade '
#                                                                    'but they '
#                                                                    'did not '
#                                                                    'receive a '
#                                                                    'high '
#                                                                    'school '
#                                                                    'diploma. '
#                                                                    'C67134'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67135',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'GED or '
#                                                              'Equivalent',
#                                          'valueMeaningCode': 'LA15619-2',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'received a '
#                                                                    'General '
#                                                                    'Equivalency '
#                                                                    'Diploma in '
#                                                                    'lieu of a '
#                                                                    'high '
#                                                                    'school '
#                                                                    'diploma. '
#                                                                    'C67135'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67136',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'HS Graduate',
#                                          'valueMeaningCode': 'LA15564-0',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'attended '
#                                                                    'high '
#                                                                    'school and '
#                                                                    'has '
#                                                                    'received a '
#                                                                    'high '
#                                                                    'school '
#                                                                    'diploma. '
#                                                                    'C67136'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67137',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Some College, No '
#                                                              'Degree',
#                                          'valueMeaningCode': 'LA15620-0',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'attended '
#                                                                    'college '
#                                                                    'but that '
#                                                                    'they did '
#                                                                    'not '
#                                                                    'receive '
#                                                                    'any '
#                                                                    'degree. '
#                                                                    'C67137'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C67141',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Occupational, '
#                                                              'Technical, or '
#                                                              'Vocational '
#                                                              'Program',
#                                          'valueMeaningCode': 'Vocational '
#                                                              'Program '
#                                                              'Completion',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'attended '
#                                                                    'or '
#                                                                    'received a '
#                                                                    'degree '
#                                                                    'from an '
#                                                                    'occupational, '
#                                                                    'technical, '
#                                                                    'or '
#                                                                    'vocational '
#                                                                    'program as '
#                                                                    'their '
#                                                                    'highest '
#                                                                    'level of '
#                                                                    'educational '
#                                                                    'achievement. '
#                                                                    'C67141'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C71340',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Associates '
#                                                              'Degree - '
#                                                              'Academic Program',
#                                          'valueMeaningCode': 'Associate '
#                                                              'Academic Degree '
#                                                              'Completion',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'received a '
#                                                                    'degree '
#                                                                    'from a 2 '
#                                                                    'year '
#                                                                    'college '
#                                                                    'program. '
#                                                                    'C71340'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C70555',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Bachelor\x92s '
#                                                              'Degree (Example: '
#                                                              'BA, AB, BS, BBA)',
#                                          'valueMeaningCode': "Bachelor's "
#                                                              'Degree '
#                                                              'Completion',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'received a '
#                                                                    'degree for '
#                                                                    'successful '
#                                                                    'completion '
#                                                                    'of a '
#                                                                    'program of '
#                                                                    'studies '
#                                                                    'that '
#                                                                    'normally '
#                                                                    'requires '
#                                                                    'at least '
#                                                                    '4-5 years '
#                                                                    'of '
#                                                                    'full-time '
#                                                                    'equivalent '
#                                                                    'college-level '
#                                                                    'work. '
#                                                                    'C70555'},
#                                         {'codeSystemName': 'LOINC',
#                                          'conceptId': 'C70556',
#                                          'conceptSource': 'NCI Thesaurus',
#                                          'permissibleValue': 'Master\x92s '
#                                                              'Degree '
#                                                              '(Example:  MA, '
#                                                              'MS, MEng, MEd, '
#                                                              'MBA)',
#                                          'valueMeaningCode': "Master's Degree "
#                                                              'Completion',
#                                          'valueMeaningDefinition': 'Indicates '
#                                                                    'that a '
#                                                                    'person has '
#                                                                    'received a '
#                                                                    'degree for '
#                                                                    'completion '
#                                                                    'of at '
#                                                                    'least one '
#                                                                    'year of '
#                                                                    'prescribed '
#                                                                    'study '
#                                                                    'beyond the '
#                                                                    "bachelor's "
#                                                                    'degree. '
#                                                                    'C70556'}]},
#   'views': 132}]

# %%
# Lets create a CSV file from my JSON elements
import csv
# Prepare the CSV file
with open('output.csv', 'w', newline='') as csvfile:
    fieldnames = ['Data Element Name', 'Question Text', 'Definition', 'Value Type', 'Permissible Values', 'Related Concepts',
                 'Registration Status', 'Identifier', "Reference URL"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    # Iterate over each entry in the JSON list
    for entry in data:
        tinyID = entry.get('tinyId')
        dataType = entry.get('valueDomain',{}).get('datatype')

        # Retrieve the name of the data element and potentially the question text to use
        designations = entry.get('designations')
        designation_list = []
        for designation in designations:
            designation_list.append(designation.get('designation',[]))
        name = designation_list[0]

        if len(designation_list) > 1:
            question = designation_list[1]
        else:
            question = designation_list[0]

        identifiers = entry.get('ids')
        if identifiers:
            identifier_list = []
            for identifier in identifiers:
                identifier_list.append((identifier.get('source',[]),identifier.get('id',[])))
            identifier_text = identifier_list[0][0] + ": " + identifier_list[0][1]
        else:
            identifier_text = ""
        # Retrieve the definition
        definitions = entry.get('definitions', [])
        definition_text = '; '.join(definition.get('definition', 'N/A') for definition in definitions)
        
        # Retrieve the permissible values
        permissible_values = entry.get('valueDomain', {}).get('permissibleValues', [])
        permissible_values_text = '; '.join(value.get('permissibleValue', 'N/A') for value in permissible_values)

        # Retrieve related concept words to enhance semantic content of record
        concepts = entry.get('dataElementConcept',{}).get('concepts',[])
        concepts_text = ' '.join(concept.get('name',"") for concept in concepts)

        registration_status = entry.get('registrationState',{}).get('registrationStatus')

        reference_text = 'https://cde.nlm.nih.gov/deView?tinyId=' + tinyID
        # Write the data to the CSV file
        writer.writerow({
            'Data Element Name': name,
            'Question Text' : question,
            'Definition': definition_text,
            'Value Type' : dataType,
            'Permissible Values': permissible_values_text,
            'Related Concepts': concepts_text,
            'Registration Status': registration_status,
            'Identifier': identifier_text,
            'Reference URL': reference_text
        })

print("CSV file has been created successfully.")
# Out:
# CSV file has been created successfully.
